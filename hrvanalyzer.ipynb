# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Create a directory in your Drive for the dataset
# !mkdir -p "/content/drive/MyDrive/Datasets/ds003823"

# Install AWS CLI (quiet install)
# !pip install awscli -q

# Download the entire dataset directly to Google Drive
# This dataset is smaller than the previous one
# !aws s3 sync --no-sign-request \
  s3://openneuro.org/ds003823 \
  "/content/drive/MyDrive/Datasets/ds003823" \
  --only-show-errors

# Verify the download - check size and file count
print("\n=== Download Summary ===")
# !du -sh "/content/drive/MyDrive/Datasets/ds003823"
# !find "/content/drive/MyDrive/Datasets/ds003823" -type f | wc -l
print("\nContents:")
# !ls -lh "/content/drive/MyDrive/Datasets/ds003823"
# Out:
# Mounted at /content/drive
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 63.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 117.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 kB 49.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 8.2.3 requires docutils<0.22,>=0.20, but you have docutils 0.19 which is incompatible.
#
# === Download Summary ===
# 220G	/content/drive/MyDrive/Datasets/ds003823
# 18042
#
# Contents:
# total 859K
# -rw------- 1 root root   36 Apr 28  2022 annex-uuid
# -rw------- 1 root root 1.4K Mar 12  2025 CHANGES
# -rw------- 1 root root 2.1K Mar 12  2025 dataset_description.json
# drwx------ 5 root root 4.0K Feb 22 16:31 derivatives
# ...
